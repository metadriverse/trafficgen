# %%
from utils.visual_init import draw_seq
import pickle

with open('../../draw.pkl', 'rb+') as f:
    datas = pickle.load(f)

# %%
dir_path = f'../../vis/snapshots/0'
draw_seq(datas['a'],datas['b'],datas['c'],edge=datas['d'],other=datas['e'],path=dir_path,save=True)
# Out:
# <module 'matplotlib.pyplot' from '/Users/fenglan/opt/anaconda3/envs/cvpr/lib/python3.7/site-packages/matplotlib/pyplot.py'>
